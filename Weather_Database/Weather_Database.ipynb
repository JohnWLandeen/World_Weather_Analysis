# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import requests
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 595

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&appid=" + weather_api_key + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_description = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | mackenzie
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | ancud
# Processing Record 5 of Set 1 | kijang
# Processing Record 6 of Set 1 | sochi
# Processing Record 7 of Set 1 | katsuura
# Processing Record 8 of Set 1 | camar
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | burica
# City not found. Skipping...
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | camacha
# Processing Record 16 of Set 1 | san ignacio
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | brigantine
# Processing Record 19 of Set 1 | rocha
# Processing Record 20 of Set 1 | kendari
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | vila velha
# Processing Record 23 of Set 1 | caravelas
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | pierre
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | samana
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | san quintin
# Processing Record 30 of Set 1 | lethem
# Processing Record 31 of Set 1 | macomb
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | rincon
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | katangli
# Processing Record 41 of Set 1 | sistranda
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | kalmunai
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | alofi
# Processing Record 47 of Set 1 | portland
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 2 | escanaba
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | asau
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | loja
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | camocim
# Processing Record 13 of Set 2 | norman wells
# Processing Record 14 of Set 2 | sao filipe
# Processing Record 15 of Set 2 | gat
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | sao felix do xingu
# Processing Record 19 of Set 2 | seddon
# Processing Record 20 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 2 | yerbogachen
# Processing Record 22 of Set 2 | kunigal
# Processing Record 23 of Set 2 | ponta delgada
# Processing Record 24 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 2 | rawlins
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | caxito
# Processing Record 29 of Set 2 | talnakh
# Processing Record 30 of Set 2 | lagoa
# Processing Record 31 of Set 2 | hovd
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | loreto
# Processing Record 35 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 2 | svetlyy
# Processing Record 37 of Set 2 | arlit
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | maragogi
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | juanjui
# Processing Record 43 of Set 2 | esperance
# Processing Record 44 of Set 2 | christchurch
# Processing Record 45 of Set 2 | ust-kuyga
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | sao joao da barra
# Processing Record 50 of Set 2 | azanka
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | isangel
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | ganzhou
# Processing Record 7 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | kupino
# Processing Record 12 of Set 3 | shihezi
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | listvyanskiy
# Processing Record 15 of Set 3 | ialibu
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | kungurtug
# Processing Record 18 of Set 3 | auki
# Processing Record 19 of Set 3 | bandarbeyla
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | ponta do sol
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | namibe
# Processing Record 24 of Set 3 | pouebo
# Processing Record 25 of Set 3 | hammerfest
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | agirish
# Processing Record 28 of Set 3 | kalaleh
# Processing Record 29 of Set 3 | keskin
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | deputatskiy
# Processing Record 32 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | coolum beach
# Processing Record 35 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 3 | kingston upon hull
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | baiyin
# Processing Record 39 of Set 3 | verkhnevilyuysk
# Processing Record 40 of Set 3 | praia da vitoria
# Processing Record 41 of Set 3 | kutum
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | guerrero negro
# Processing Record 45 of Set 3 | manaus
# Processing Record 46 of Set 3 | cervo
# Processing Record 47 of Set 3 | vitim
# Processing Record 48 of Set 3 | najran
# Processing Record 49 of Set 3 | tiarei
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | mocuba
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | botwood
# Processing Record 4 of Set 4 | taywarah
# Processing Record 5 of Set 4 | san cristobal
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | nikolskoye
# Processing Record 9 of Set 4 | matara
# Processing Record 10 of Set 4 | shaunavon
# Processing Record 11 of Set 4 | hilo
# Processing Record 12 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 4 | hobart
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | demirci
# Processing Record 17 of Set 4 | bilma
# Processing Record 18 of Set 4 | saint-joseph
# Processing Record 19 of Set 4 | dhidhdhoo
# Processing Record 20 of Set 4 | petropavlovka
# Processing Record 21 of Set 4 | saskylakh
# Processing Record 22 of Set 4 | souillac
# Processing Record 23 of Set 4 | allapalli
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | saint anthony
# Processing Record 26 of Set 4 | beitbridge
# Processing Record 27 of Set 4 | chulym
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 30 of Set 4 | male
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | kerrville
# Processing Record 33 of Set 4 | wilmington
# Processing Record 34 of Set 4 | seydi
# Processing Record 35 of Set 4 | hambantota
# Processing Record 36 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 37 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 4 | karratha
# Processing Record 39 of Set 4 | waverly
# Processing Record 40 of Set 4 | witu
# Processing Record 41 of Set 4 | diamantino
# Processing Record 42 of Set 4 | ryotsu
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | chara
# Processing Record 45 of Set 4 | dali
# Processing Record 46 of Set 4 | coahuayana
# Processing Record 47 of Set 4 | ulyanovo
# City not found. Skipping...
# Processing Record 48 of Set 4 | chulman
# Processing Record 49 of Set 4 | omboue
# Processing Record 50 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 5 | sirohi
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 5 | aksay
# Processing Record 7 of Set 5 | husavik
# Processing Record 8 of Set 5 | mpulungu
# Processing Record 9 of Set 5 | santa cruz
# Processing Record 10 of Set 5 | manzhouli
# Processing Record 11 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | mayo
# Processing Record 13 of Set 5 | lakes entrance
# Processing Record 14 of Set 5 | guangyuan
# Processing Record 15 of Set 5 | half moon bay
# Processing Record 16 of Set 5 | tilichiki
# Processing Record 17 of Set 5 | ust-maya
# Processing Record 18 of Set 5 | santa rosa
# Processing Record 19 of Set 5 | pontiac
# Processing Record 20 of Set 5 | pevek
# Processing Record 21 of Set 5 | komyshuvakha
# Processing Record 22 of Set 5 | derzhavinsk
# Processing Record 23 of Set 5 | kermanshah
# Processing Record 24 of Set 5 | morehead
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | torrington
# Processing Record 27 of Set 5 | bambous virieux
# Processing Record 28 of Set 5 | pahrump
# Processing Record 29 of Set 5 | champerico
# Processing Record 30 of Set 5 | fare
# Processing Record 31 of Set 5 | vila franca do campo
# Processing Record 32 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | kununurra
# Processing Record 35 of Set 5 | iranshahr
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | college
# Processing Record 38 of Set 5 | kuantan
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | saint-georges
# Processing Record 43 of Set 5 | kismayo
# Processing Record 44 of Set 5 | naze
# Processing Record 45 of Set 5 | kokopo
# Processing Record 46 of Set 5 | itapetininga
# Processing Record 47 of Set 5 | kabo
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | cayenne
# Processing Record 50 of Set 5 | uribia
# Processing Record 1 of Set 6 | farafangana
# Processing Record 2 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 6 | lokosovo
# Processing Record 4 of Set 6 | vardo
# Processing Record 5 of Set 6 | locri
# Processing Record 6 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 6 | alice town
# Processing Record 8 of Set 6 | noumea
# Processing Record 9 of Set 6 | skovde
# City not found. Skipping...
# Processing Record 10 of Set 6 | nioro
# Processing Record 11 of Set 6 | ruwi
# Processing Record 12 of Set 6 | bilibino
# Processing Record 13 of Set 6 | kyaukse
# Processing Record 14 of Set 6 | axim
# Processing Record 15 of Set 6 | dryden
# Processing Record 16 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | aklavik
# Processing Record 19 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 6 | stonehouse
# Processing Record 21 of Set 6 | muscat
# Processing Record 22 of Set 6 | marzuq
# Processing Record 23 of Set 6 | gambo
# Processing Record 24 of Set 6 | lebedyn
# Processing Record 25 of Set 6 | ohara
# Processing Record 26 of Set 6 | arawa
# Processing Record 27 of Set 6 | mizdah
# Processing Record 28 of Set 6 | sassandra
# Processing Record 29 of Set 6 | ambon
# Processing Record 30 of Set 6 | bogorodskoye
# Processing Record 31 of Set 6 | seevetal
# Processing Record 32 of Set 6 | sahuaripa
# Processing Record 33 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 6 | pombal
# Processing Record 35 of Set 6 | verkhoyansk
# Processing Record 36 of Set 6 | san pedro
# Processing Record 37 of Set 6 | vilhena
# Processing Record 38 of Set 6 | maceio
# Processing Record 39 of Set 6 | padang
# Processing Record 40 of Set 6 | atar
# Processing Record 41 of Set 6 | harrison
# Processing Record 42 of Set 6 | guarapari
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | sitka
# Processing Record 45 of Set 6 | mutare
# Processing Record 46 of Set 6 | mastic beach
# Processing Record 47 of Set 6 | rawson
# Processing Record 48 of Set 6 | copiapo
# Processing Record 49 of Set 6 | konya
# Processing Record 50 of Set 6 | halifax
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | biak
# Processing Record 3 of Set 7 | bure
# Processing Record 4 of Set 7 | necochea
# Processing Record 5 of Set 7 | lucea
# Processing Record 6 of Set 7 | bredasdorp
# Processing Record 7 of Set 7 | calama
# Processing Record 8 of Set 7 | pangnirtung
# Processing Record 9 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 7 | matinha
# Processing Record 11 of Set 7 | ribeira grande
# Processing Record 12 of Set 7 | hobyo
# Processing Record 13 of Set 7 | srednekolymsk
# Processing Record 14 of Set 7 | lagos
# Processing Record 15 of Set 7 | roebourne
# Processing Record 16 of Set 7 | neftcala
# Processing Record 17 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 18 of Set 7 | marquette
# Processing Record 19 of Set 7 | buala
# Processing Record 20 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 7 | sumbe
# Processing Record 22 of Set 7 | fremont
# Processing Record 23 of Set 7 | parana
# Processing Record 24 of Set 7 | chapais
# Processing Record 25 of Set 7 | caibarien
# Processing Record 26 of Set 7 | mitsamiouli
# Processing Record 27 of Set 7 | bethel
# Processing Record 28 of Set 7 | oriximina
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | klaksvik
# Processing Record 31 of Set 7 | harper
# Processing Record 32 of Set 7 | gwadar
# Processing Record 33 of Set 7 | santa maria da vitoria
# Processing Record 34 of Set 7 | greenville
# Processing Record 35 of Set 7 | grindavik
# Processing Record 36 of Set 7 | belmonte
# Processing Record 37 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 38 of Set 7 | motema
# Processing Record 39 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 7 | juodupe
# Processing Record 41 of Set 7 | san carlos de bariloche
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | bosaso
# Processing Record 44 of Set 7 | itoman
# Processing Record 45 of Set 7 | ambilobe
# Processing Record 46 of Set 7 | aljezur
# Processing Record 47 of Set 7 | kirgiz-miyaki
# Processing Record 48 of Set 7 | moerai
# Processing Record 49 of Set 7 | aras
# Processing Record 50 of Set 7 | inverell
# Processing Record 1 of Set 8 | hakodate
# Processing Record 2 of Set 8 | novyy urgal
# Processing Record 3 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 4 of Set 8 | shingu
# Processing Record 5 of Set 8 | akhtubinsk
# Processing Record 6 of Set 8 | moyobamba
# Processing Record 7 of Set 8 | constitucion
# Processing Record 8 of Set 8 | moron
# Processing Record 9 of Set 8 | zhaotong
# Processing Record 10 of Set 8 | kidal
# Processing Record 11 of Set 8 | dharchula
# Processing Record 12 of Set 8 | tutoia
# Processing Record 13 of Set 8 | chuy
# Processing Record 14 of Set 8 | soteapan
# Processing Record 15 of Set 8 | akkermanovka
# Processing Record 16 of Set 8 | richards bay
# Processing Record 17 of Set 8 | latur
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | port blair
# Processing Record 20 of Set 8 | flin flon
# Processing Record 21 of Set 8 | alpena
# Processing Record 22 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 8 | fez
# Processing Record 24 of Set 8 | langxiang
# Processing Record 25 of Set 8 | sioux lookout
# Processing Record 26 of Set 8 | trelleborg
# Processing Record 27 of Set 8 | ouallam
# Processing Record 28 of Set 8 | whitehorse
# Processing Record 29 of Set 8 | sungaipenuh
# Processing Record 30 of Set 8 | ulfborg
# Processing Record 31 of Set 8 | spasskoye
# Processing Record 32 of Set 8 | adrar
# Processing Record 33 of Set 8 | luanda
# Processing Record 34 of Set 8 | yueyang
# Processing Record 35 of Set 8 | emerald
# Processing Record 36 of Set 8 | balabac
# Processing Record 37 of Set 8 | kaoma
# Processing Record 38 of Set 8 | kemijarvi
# Processing Record 39 of Set 8 | haines junction
# Processing Record 40 of Set 8 | grenfell
# Processing Record 41 of Set 8 | shulan
# Processing Record 42 of Set 8 | labuhan
# Processing Record 43 of Set 8 | narsaq
# Processing Record 44 of Set 8 | sidhi
# Processing Record 45 of Set 8 | oranjemund
# Processing Record 46 of Set 8 | san isidro
# Processing Record 47 of Set 8 | pointe michel
# Processing Record 48 of Set 8 | rabak
# Processing Record 49 of Set 8 | naukot
# Processing Record 50 of Set 8 | dongobesh
# Processing Record 1 of Set 9 | bayji
# Processing Record 2 of Set 9 | kubrat
# Processing Record 3 of Set 9 | novo cruzeiro
# Processing Record 4 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 5 of Set 9 | poum
# Processing Record 6 of Set 9 | kavaratti
# Processing Record 7 of Set 9 | mount gambier
# Processing Record 8 of Set 9 | kaeo
# Processing Record 9 of Set 9 | uzumlu
# City not found. Skipping...
# Processing Record 10 of Set 9 | lavrentiya
# Processing Record 11 of Set 9 | bereda
# Processing Record 12 of Set 9 | meulaboh
# Processing Record 13 of Set 9 | tommot
# Processing Record 14 of Set 9 | longjiang
# Processing Record 15 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 9 | west bend
# Processing Record 17 of Set 9 | birao
# Processing Record 18 of Set 9 | ixtapa
# Processing Record 19 of Set 9 | fortuna
# Processing Record 20 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 9 | isla vista
# Processing Record 22 of Set 9 | havre-saint-pierre
# Processing Record 23 of Set 9 | plouzane
# Processing Record 24 of Set 9 | namatanai
# Processing Record 25 of Set 9 | warmbad
# Processing Record 26 of Set 9 | nabire
# Processing Record 27 of Set 9 | kahului
# Processing Record 28 of Set 9 | cradock
# Processing Record 29 of Set 9 | maumere
# Processing Record 30 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 31 of Set 9 | campbellton
# Processing Record 32 of Set 9 | qingdao
# Processing Record 33 of Set 9 | ternate
# Processing Record 34 of Set 9 | wagar
# Processing Record 35 of Set 9 | garissa
# Processing Record 36 of Set 9 | antalaha
# Processing Record 37 of Set 9 | bocas del toro
# Processing Record 38 of Set 9 | yining
# Processing Record 39 of Set 9 | vestmannaeyjar
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | mulege
# Processing Record 42 of Set 9 | hokitika
# Processing Record 43 of Set 9 | ano mera
# Processing Record 44 of Set 9 | cabo san lucas
# Processing Record 45 of Set 9 | baghmara
# Processing Record 46 of Set 9 | olinda
# Processing Record 47 of Set 9 | soyo
# Processing Record 48 of Set 9 | requena
# Processing Record 49 of Set 9 | aviles
# Processing Record 50 of Set 9 | tazovskiy
# Processing Record 1 of Set 10 | ziarat
# Processing Record 2 of Set 10 | simpang
# Processing Record 3 of Set 10 | dabola
# Processing Record 4 of Set 10 | kargil
# Processing Record 5 of Set 10 | pitimbu
# Processing Record 6 of Set 10 | kavieng
# Processing Record 7 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 8 of Set 10 | savannah bight
# Processing Record 9 of Set 10 | bonavista
# Processing Record 10 of Set 10 | tautira
# Processing Record 11 of Set 10 | saint george
# Processing Record 12 of Set 10 | fort nelson
# Processing Record 13 of Set 10 | nichinan
# Processing Record 14 of Set 10 | marawi
# Processing Record 15 of Set 10 | dosso
# Processing Record 16 of Set 10 | bowmore
# Processing Record 17 of Set 10 | ellisras
# Processing Record 18 of Set 10 | monastyrshchina
# Processing Record 19 of Set 10 | muncar
# Processing Record 20 of Set 10 | nkan
# Processing Record 21 of Set 10 | fairfield
# Processing Record 22 of Set 10 | san patricio
# Processing Record 23 of Set 10 | lima
# Processing Record 24 of Set 10 | geraldton
# Processing Record 25 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 10 | avera
# Processing Record 27 of Set 10 | shelburne
# Processing Record 28 of Set 10 | koslan
# Processing Record 29 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 10 | buzim
# Processing Record 31 of Set 10 | pathein
# Processing Record 32 of Set 10 | kingman
# Processing Record 33 of Set 10 | shamary
# Processing Record 34 of Set 10 | broken hill
# Processing Record 35 of Set 10 | zhigansk
# Processing Record 36 of Set 10 | careiro da varzea
# Processing Record 37 of Set 10 | south charleston
# Processing Record 38 of Set 10 | sinjar
# Processing Record 39 of Set 10 | taga
# Processing Record 40 of Set 10 | trincomalee
# Processing Record 41 of Set 10 | simao
# Processing Record 42 of Set 10 | palu
# Processing Record 43 of Set 10 | kathu
# Processing Record 44 of Set 10 | bathurst
# Processing Record 45 of Set 10 | qena
# Processing Record 46 of Set 10 | laguna
# Processing Record 47 of Set 10 | jackson
# Processing Record 48 of Set 10 | chitral
# Processing Record 49 of Set 10 | leh
# Processing Record 50 of Set 10 | japura
# Processing Record 1 of Set 11 | lazaro cardenas
# Processing Record 2 of Set 11 | tura
# Processing Record 3 of Set 11 | ponerihouen
# Processing Record 4 of Set 11 | zabol
# Processing Record 5 of Set 11 | miri
# Processing Record 6 of Set 11 | nouadhibou
# Processing Record 7 of Set 11 | athni
# Processing Record 8 of Set 11 | alyangula
# Processing Record 9 of Set 11 | kibaya
# Processing Record 10 of Set 11 | mezen
# Processing Record 11 of Set 11 | santa maria
# Processing Record 12 of Set 11 | benjamin constant
# Processing Record 13 of Set 11 | libreville
# Processing Record 14 of Set 11 | ahipara
# Processing Record 15 of Set 11 | te anau
# Processing Record 16 of Set 11 | xichang
# Processing Record 17 of Set 11 | peplos
# Processing Record 18 of Set 11 | sicamous
# Processing Record 19 of Set 11 | leningradskiy
# Processing Record 20 of Set 11 | surt
# Processing Record 21 of Set 11 | norwich
# Processing Record 22 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 11 | ondjiva
# Processing Record 24 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 11 | mehamn
# Processing Record 26 of Set 11 | mizan teferi
# Processing Record 27 of Set 11 | chumikan
# Processing Record 28 of Set 11 | jizan
# Processing Record 29 of Set 11 | millinocket
# Processing Record 30 of Set 11 | dingle
# Processing Record 31 of Set 11 | rudbar
# Processing Record 32 of Set 11 | lompoc
# Processing Record 33 of Set 11 | orhei
# Processing Record 34 of Set 11 | owando
# Processing Record 35 of Set 11 | alta floresta
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | takhtamygda
# Processing Record 38 of Set 11 | porto novo
# Processing Record 39 of Set 11 | dossor
# Processing Record 40 of Set 11 | colares
# Processing Record 41 of Set 11 | hamilton
# Processing Record 42 of Set 11 | victoria
# Processing Record 43 of Set 11 | nikel
# Processing Record 44 of Set 11 | yuancheng
# Processing Record 45 of Set 11 | bayir
# Processing Record 46 of Set 11 | sobolevo
# Processing Record 47 of Set 11 | port keats
# Processing Record 48 of Set 11 | qarqin
# Processing Record 49 of Set 11 | kuruman
# Processing Record 50 of Set 11 | eyl
# Processing Record 1 of Set 12 | rundu
# Processing Record 2 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 3 of Set 12 | luderitz
# Processing Record 4 of Set 12 | rorvik
# Processing Record 5 of Set 12 | fukue
# Processing Record 6 of Set 12 | gerash
# Processing Record 7 of Set 12 | lorengau
# Processing Record 8 of Set 12 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 9 of Set 12 | puri
# Processing Record 10 of Set 12 | altoona
# Processing Record 11 of Set 12 | mapiripan
# Processing Record 12 of Set 12 | martapura
# Processing Record 13 of Set 12 | quang ngai
# Processing Record 14 of Set 12 | itarema
# Processing Record 15 of Set 12 | fairburn
# Processing Record 16 of Set 12 | los llanos de aridane
# Processing Record 17 of Set 12 | ulaanbaatar
# Processing Record 18 of Set 12 | ruteng
# Processing Record 19 of Set 12 | nizwa
# Processing Record 20 of Set 12 | nueve de julio
# Processing Record 21 of Set 12 | san juan
# Processing Record 22 of Set 12 | luena
# Processing Record 23 of Set 12 | rio verde de mato grosso
# Processing Record 24 of Set 12 | minsk
# Processing Record 25 of Set 12 | mawlaik
# Processing Record 26 of Set 12 | tamale
# Processing Record 27 of Set 12 | san vicente
# Processing Record 28 of Set 12 | manicore
# Processing Record 29 of Set 12 | poitiers
# Processing Record 30 of Set 12 | muros
# Processing Record 31 of Set 12 | zaysan
# Processing Record 32 of Set 12 | hazorasp
# Processing Record 33 of Set 12 | mishkino
# Processing Record 34 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 12 | shache
# Processing Record 36 of Set 12 | mathbaria
# Processing Record 37 of Set 12 | puertollano
# Processing Record 38 of Set 12 | jiayuguan
# Processing Record 39 of Set 12 | seoul
# Processing Record 40 of Set 12 | inuvik
# Processing Record 41 of Set 12 | auchi
# Processing Record 42 of Set 12 | luganville
# Processing Record 43 of Set 12 | nchelenge
# Processing Record 44 of Set 12 | andros town
# Processing Record 45 of Set 12 | loding
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ushuaia      AR -54.8000  -68.3000    267.04        91          50
# 1  Mackenzie      CA  55.2999 -123.1698    289.82        64         100
# 2      Vaini      TO -21.2000 -175.2000    295.36        63          91
# 3      Ancud      CL -41.8697  -73.8203    278.83        92         100
# 4     Kijang      KR  35.2442  129.2139    299.60        79         100
# 5      Sochi      RU  43.6000   39.7303    292.20        66           9
# 6   Katsuura      JP  35.1333  140.3000    300.86        75          99
# 7      Camar      RO  47.3000   22.6167    293.88        60          64
# 8   Sisimiut      GL  66.9395  -53.6735    278.69        92          49
# 9     Faanui      PF -16.4833 -151.7500    299.55        73           7
#
#    Wind Speed Current Description
# 0        1.91    scattered clouds
# 1        1.17     overcast clouds
# 2        9.45     overcast clouds
# 3        1.22          light rain
# 4        7.09     overcast clouds
# 5        1.06           clear sky
# 6        6.38     overcast clouds
# 7        2.36       broken clouds
# 8        1.85    scattered clouds
# 9        5.21          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
